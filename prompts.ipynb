# %% [markdown]
# ## Assignment 3

# %%
# pip install openai
# %pip install openai
# Out:
# Requirement already satisfied: openai in c:\users\rowan\anaconda3\lib\site-packages (1.75.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\rowan\anaconda3\lib\site-packages (from openai) (3.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\rowan\anaconda3\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\rowan\anaconda3\lib\site-packages (from openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\rowan\anaconda3\lib\site-packages (from openai) (0.9.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\rowan\anaconda3\lib\site-packages (from openai) (2.11.3)
# Requirement already satisfied: sniffio in c:\users\rowan\anaconda3\lib\site-packages (from openai) (1.2.0)
# Requirement already satisfied: tqdm>4 in c:\users\rowan\anaconda3\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\rowan\anaconda3\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\rowan\anaconda3\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.3)
# Requirement already satisfied: certifi in c:\users\rowan\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (2021.10.8)
# Requirement already satisfied: httpcore==1.* in c:\users\rowan\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.8)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\rowan\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\rowan\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\rowan\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\rowan\anaconda3\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.4.0)
# Requirement already satisfied: colorama in c:\users\rowan\anaconda3\lib\site-packages (from tqdm>4->openai) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from openai import OpenAI

# Create your PAT token by following instructions here: 
# https://docs.github.com/en/authentication/keeping-your-account-and-data-secure/managing-your-personal-access-tokens
# grab the token from the token.txt file
with open("token.txt", "r") as f:
    GITHUB_TOKEN = f.read().strip()

# To authenticate with the model you will need to generate a personal access token (PAT) in your GitHub settings. 
client = OpenAI(
    base_url="https://models.inference.ai.azure.com",
    api_key=GITHUB_TOKEN,
)

models = ["gpt-4o-mini" , "Codestral-2501"]

# %% [markdown]
# ## Task 1: Code Explanation
#
# Objective: Use gpt-4o-mini and DeepSeek-R1 to explain a function.
#
# Activity:
#
# - Try different models
# - Note differences in explanation
# - Play around with temperature values (range [0,1]), maximum number of tokens
# - Which model explains better for beginners?

# %%
code = '''
public Map < String , Integer > countWordFrequency ( List < String > words ) {
    Map < String , Integer > freqMap = new HashMap < >() ;
    for ( String word : words ) {
        freqMap . put ( word , freqMap . getOrDefault ( word , 0) + 1) ;
    }
    return freqMap ;
}
'''

# %%
response = client.chat.completions.create(
    model = "gpt-4o", # Choose the model you want to use
    messages=[
        {"role": "user", 
         "content": f"Summarize the functionality of the following Java method:\n{code}"
         },
    ],
    max_tokens=1024,
    temperature=0.7,
)

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 response = client.chat.completions.create(
#       2     model = "gpt-4o-mini", # Choose the model you want to use
#       3     messages=[
#       4         {"role": "user",
#       5          "content": f"Summarize the functionality of the following Java method:\n{code}"
#       6          },
#       7     ],
#       8     max_tokens=1024,
#       9     temperature=0.7,
#      10 )
#      12 print(response.choices[0].message.content)
#
# File c:\Users\rowan\anaconda3\lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File c:\Users\rowan\anaconda3\lib\site-packages\openai\resources\chat\completions\completions.py:929, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     886 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     887 def create(
#     888     self,
#    (...)
#     926     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     927 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     928     validate_response_format(response_format)
# --> 929     return self._post(
#     930         "/chat/completions",
#     931         body=maybe_transform(
#     932             {
#     933                 "messages": messages,
#     934                 "model": model,
#     935                 "audio": audio,
#     936                 "frequency_penalty": frequency_penalty,
#     937                 "function_call": function_call,
#     938                 "functions": functions,
#     939                 "logit_bias": logit_bias,
#     940                 "logprobs": logprobs,
#     941                 "max_completion_tokens": max_completion_tokens,
#     942                 "max_tokens": max_tokens,
#     943                 "metadata": metadata,
#     944                 "modalities": modalities,
#     945                 "n": n,
#     946                 "parallel_tool_calls": parallel_tool_calls,
#     947                 "prediction": prediction,
#     948                 "presence_penalty": presence_penalty,
#     949                 "reasoning_effort": reasoning_effort,
#     950                 "response_format": response_format,
#     951                 "seed": seed,
#     952                 "service_tier": service_tier,
#     953                 "stop": stop,
#     954                 "store": store,
#     955                 "stream": stream,
#     956                 "stream_options": stream_options,
#     957                 "temperature": temperature,
#     958                 "tool_choice": tool_choice,
#     959                 "tools": tools,
#     960                 "top_logprobs": top_logprobs,
#     961                 "top_p": top_p,
#     962                 "user": user,
#     963                 "web_search_options": web_search_options,
#     964             },
#     965             completion_create_params.CompletionCreateParamsStreaming
#     966             if stream
#     967             else completion_create_params.CompletionCreateParamsNonStreaming,
#     968         ),
#     969         options=make_request_options(
#     970             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     971         ),
#     972         cast_to=ChatCompletion,
#     973         stream=stream or False,
#     974         stream_cls=Stream[ChatCompletionChunk],
#     975     )
#
# File c:\Users\rowan\anaconda3\lib\site-packages\openai\_base_client.py:1276, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1262 def post(
#    1263     self,
#    1264     path: str,
#    (...)
#    1271     stream_cls: type[_StreamT] | None = None,
#    1272 ) -> ResponseT | _StreamT:
#    1273     opts = FinalRequestOptions.construct(
#    1274         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1275     )
# -> 1276     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\rowan\anaconda3\lib\site-packages\openai\_base_client.py:949, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     946 else:
#     947     retries_taken = 0
# --> 949 return self._request(
#     950     cast_to=cast_to,
#     951     options=options,
#     952     stream=stream,
#     953     stream_cls=stream_cls,
#     954     retries_taken=retries_taken,
#     955 )
#
# File c:\Users\rowan\anaconda3\lib\site-packages\openai\_base_client.py:1057, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1054         err.response.read()
#    1056     log.debug("Re-raising status error")
# -> 1057     raise self._make_status_error_from_response(err.response) from None
#    1059 return self._process_response(
#    1060     cast_to=cast_to,
#    1061     options=options,
#    (...)
#    1065     retries_taken=retries_taken,
#    1066 )
#
# AuthenticationError: Error code: 401 - {'error': {'code': 'unauthorized', 'message': 'Bad credentials', 'details': 'Bad credentials'}}

# %% [markdown]
# ## Task 2: Code Translation
#
# Activity:
# - Translate this function.
#
# - Copy Java output and test if the model translates the Java code back to Python correctly.
#
# - Play around with temperature.
#
# - Use another model for comparison.

# %%
# Example code to test the model
# This code calculates the factorial of a number n
code = '''
def factorial(n):
    return 1 if n == 0 else n * factorial(n - 1)
'''

java_code = ''' '''

response = client.chat.completions.create(
    model = models[1], # Choose the model you want to use
    messages=[
        {"role": "user", 
         "content": f"Translate this Python code to Java:\n{code}"
         },
    ],
    max_tokens=1024,
    temperature=0.7,
)

print(response.choices[0].message.content)
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# Input In [7], in <cell line: 10>()
#       3 code = '''
#       4 def factorial(n):
#       5     return 1 if n == 0 else n * factorial(n - 1)
#       6 '''
#       8 java_code = ''' '''
# ---> 10 response = client.chat.completions.create(
#      11     model = models[1], # Choose the model you want to use
#      12     messages=[
#      13         {"role": "user",
#      14          "content": f"Translate this Python code to Java:\n{code}"
#      15          },
#      16     ],
#      17     max_tokens=1024,
#      18     temperature=0.7,
#      19 )
#      21 print(response.choices[0].message.content)
#
# File c:\Users\rowan\anaconda3\lib\site-packages\openai\_utils\_utils.py:279, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     277             msg = f"Missing required argument: {quote(missing[0])}"
#     278     raise TypeError(msg)
# --> 279 return func(*args, **kwargs)
#
# File c:\Users\rowan\anaconda3\lib\site-packages\openai\resources\chat\completions\completions.py:929, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#     886 @required_args(["messages", "model"], ["messages", "model", "stream"])
#     887 def create(
#     888     self,
#    (...)
#     926     timeout: float | httpx.Timeout | None | NotGiven = NOT_GIVEN,
#     927 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#     928     validate_response_format(response_format)
# --> 929     return self._post(
#     930         "/chat/completions",
#     931         body=maybe_transform(
#     932             {
#     933                 "messages": messages,
#     934                 "model": model,
#     935                 "audio": audio,
#     936                 "frequency_penalty": frequency_penalty,
#     937                 "function_call": function_call,
#     938                 "functions": functions,
#     939                 "logit_bias": logit_bias,
#     940                 "logprobs": logprobs,
#     941                 "max_completion_tokens": max_completion_tokens,
#     942                 "max_tokens": max_tokens,
#     943                 "metadata": metadata,
#     944                 "modalities": modalities,
#     945                 "n": n,
#     946                 "parallel_tool_calls": parallel_tool_calls,
#     947                 "prediction": prediction,
#     948                 "presence_penalty": presence_penalty,
#     949                 "reasoning_effort": reasoning_effort,
#     950                 "response_format": response_format,
#     951                 "seed": seed,
#     952                 "service_tier": service_tier,
#     953                 "stop": stop,
#     954                 "store": store,
#     955                 "stream": stream,
#     956                 "stream_options": stream_options,
#     957                 "temperature": temperature,
#     958                 "tool_choice": tool_choice,
#     959                 "tools": tools,
#     960                 "top_logprobs": top_logprobs,
#     961                 "top_p": top_p,
#     962                 "user": user,
#     963                 "web_search_options": web_search_options,
#     964             },
#     965             completion_create_params.CompletionCreateParamsStreaming
#     966             if stream
#     967             else completion_create_params.CompletionCreateParamsNonStreaming,
#     968         ),
#     969         options=make_request_options(
#     970             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     971         ),
#     972         cast_to=ChatCompletion,
#     973         stream=stream or False,
#     974         stream_cls=Stream[ChatCompletionChunk],
#     975     )
#
# File c:\Users\rowan\anaconda3\lib\site-packages\openai\_base_client.py:1276, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1262 def post(
#    1263     self,
#    1264     path: str,
#    (...)
#    1271     stream_cls: type[_StreamT] | None = None,
#    1272 ) -> ResponseT | _StreamT:
#    1273     opts = FinalRequestOptions.construct(
#    1274         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1275     )
# -> 1276     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\rowan\anaconda3\lib\site-packages\openai\_base_client.py:949, in SyncAPIClient.request(self, cast_to, options, remaining_retries, stream, stream_cls)
#     946 else:
#     947     retries_taken = 0
# --> 949 return self._request(
#     950     cast_to=cast_to,
#     951     options=options,
#     952     stream=stream,
#     953     stream_cls=stream_cls,
#     954     retries_taken=retries_taken,
#     955 )
#
# File c:\Users\rowan\anaconda3\lib\site-packages\openai\_base_client.py:1057, in SyncAPIClient._request(self, cast_to, options, retries_taken, stream, stream_cls)
#    1054         err.response.read()
#    1056     log.debug("Re-raising status error")
# -> 1057     raise self._make_status_error_from_response(err.response) from None
#    1059 return self._process_response(
#    1060     cast_to=cast_to,
#    1061     options=options,
#    (...)
#    1065     retries_taken=retries_taken,
#    1066 )
#
# AuthenticationError: Error code: 401 - {'error': {'code': 'unauthorized', 'message': 'Bad credentials', 'details': 'Bad credentials'}}

# %% [markdown]
# ## Task 3: Code Debugging
#
# Activity:
# - Identify the syntax bug.
# - Ask the model to explain the fix.

# %%
buggy_code = '''
def is_even(num):
    return num % 2 = 0
'''

response = client.chat.completions.create(
    model=model_choices[1], # Choose the model you want to use
    messages=[
        {"role": "user", 
         "content": f"Identify the bug in this code:\n{buggy_code}"
         },
    ],
    max_tokens=1024,
    temperature=0.7,
)
print(response.choices[0].message.content)

# %% [markdown]
# ## Task 4: Code Review
#
# Activity:
# - Note suggestions on performance or readability.
#
# - Try the same with other models — are the suggestions different?

# %%
code = '''
def calculate_total(items):
    total = 0
    for i in range(len(items)):
        total = total + items[i]
    return total
'''

response = client.chat.completions.create(
    model=model_choices[1], # Choose the model you want to use
    messages=[
        {"role": "user", 
         "content": f"Review this code and suggest improvements:\n{code}"},
    ]
)

print(response.choices[0].message.content)

# %% [markdown]
# ## Task 5: Code Optimization
#
# Activity:
# - Note suggestions on how to optimize the code.
#
# - Try the same with other models — are the suggestions different?

# %%
# Example code to test the model
# This code calculates the Fibonacci sequence up to n
code = '''
def fibonacci(n):
    fib = [0, 1]
    for i in range(2, n):
        fib.append(fib[i-1] + fib[i-2])
    return fib
''' 

response = client.chat.completions.create(
    model=model_choices[0], # Choose the model you want to use
    messages=[
        {"role": "user", 
         "content": f"Optimize this code:\n{code}"
         },
    ],
    max_tokens=1024,
    temperature=0.7,
)
print(response.choices[0].message.content)

# %% [markdown]
# ## Task 6: Back-and-Forth Coding Conversation
#
# Objective:  Simulate an interactive chat with an AI model to iteratively develop or fix code.
#
# Activities:
#
# - Maintain conversation context
# - Refine prompts based on model feedback
# - Note whether the model remembers context well
# - Was the conversation coherent and helpful?
# - How would this differ from searching Stack Overflow?

# %%
# Starter example for chat-based interaction
# Set up conversation history
messages = [
    {"role": "system", "content": "You are a helpful coding assistant."},
    {"role": "user", "content": "I want to write a Python function that reverses a string."}
]

# Call the model
response = client.chat.completions.create(
    model=model_choices[0], # Choose the model you want to use
    max_tokens=1024,
    temperature=0.7,
    messages=messages
)

# Print the response
reply = response.choices[0].message.content
print("Assistant:", reply)

# Add response to the conversation
messages.append({"role": "assistant", "content": reply})

# User follows up
followup = "Can you also make it ignore whitespace and punctuation?"

# Add user message
messages.append({"role": "user", "content": followup})

# Call again with updated history
response = client.chat.completions.create(
    model=model_choices[0], # Choose the model you want to use
    max_tokens=1024,
    temperature=0.7,
    messages=messages
)

print("Assistant:", response.choices[0].message.content)

# %% [markdown]
# ## PUSHING THE BOUNDARIES: BEYOND METHODS
# You’re parsing a configuration file (or structured log) line-by-line and converting it to structured output. The code runs fine, outputs valid results, but fails silently in edge cases due to a bad assumption about the input structure. Let's use the o1 gpt model to design a pipeline that first detects the issues and then it also introduces test cases

# %%
# Starter example for chat-based interaction
# Set up conversation history
messages = [
    {"role": "system", "content": "You are a helpful coding assistant."},
    {"role": "user", "content": "I wrote a Python script to parse a config file with sections and key-value pairs. Let's inspect the code to make sure is bug-free\n\n" + open("config_parser.py").read()}
]

# Call the model
response = client.chat.completions.create(
    model=model_choices[0],  # Choose the model you want to use
    max_tokens=1024,
    temperature=0.4,
    messages=messages
)

print("***************************************************************************\n\n")

# Print the response
reply = response.choices[0].message.content
print("Assistant:", reply)

# Add response to the conversation
messages.append({"role": "assistant", "content": reply})

# User follows up with refinement request
followup = "Can you also suggest some unit tests for this code?"

# Add user message
messages.append({"role": "user", "content": followup})

# Call again with updated history
response = client.chat.completions.create(
    model=model_choices[0],  # Choose the model you want to use
    max_tokens=1024,
    temperature=0.4,
    messages=messages
)

print("Assistant:", response.choices[0].message.content)
# Out:
# Assistant: Your Python script for parsing a config file looks quite good overall, but there are a few areas that could be improved or that might lead to potential issues. Let's go through them:
#
# 1. **Silent Ignoring of Keys Before Any Section**: As you noted in the comment, the script silently ignores any key-value pairs that appear before any section is defined. This could lead to confusion if users expect those key-value pairs to be part of a default section. You might want to raise an error or log a warning if key-value pairs are found before any section.
#
# 2. **Handling Multiple Equal Signs**: The current implementation assumes there is only one `=` in each line. If a line contains multiple `=` signs, it will only use the first one. You might want to handle this case explicitly, either by raising an error or by allowing the rest of the line to be part of the value.
#
# 3. **Stripping Whitespace**: You are correctly stripping whitespace from both keys and values, which is good practice.
#
# 4. **Handling Nested Sections**: If the config file allows nested sections (e.g., `[Section:Subsection]`), the current implementation doesn't handle this. Depending on your requirements, you might want to consider how to manage nested sections.
#
# 5. **File Handling**: The script uses a context manager (`with open(...)`) which is great for resource management. Just ensure that the file path is correct and that the file exists to avoid `FileNotFoundError`.
#
# 6. **Error Handling**: Consider adding error handling for cases like malformed lines or unexpected formats. This will make your script more robust.
#
# Here’s a modified version of your code with some of these suggestions implemented:
#
# ```python
# def parse_config(filepath):
#     config = {}
#     current_section = None
#
#     with open(filepath, 'r') as f:
#         for line in f:
#             line = line.strip()
#             if not line or line.startswith("#"):
#                 continue
#             if line.startswith("[") and line.endswith("]"):
#                 current_section = line[1:-1]
#                 config[current_section] = {}
#             else:
#                 if current_section is None:
#                     print(f"Warning: Found key-value pair before any section: {line}")
#                     continue  # Optionally, raise an error here
#                 if '=' in line:
#                     key, value = line.split('=', 1)  # Split only on the first '='
#                     config[current_section][key.strip()] = value.strip()
#                 else:
#                     print(f"Warning: Malformed line (no '=' found): {line}")
#     return config
#
# def main():
#     config = parse_config("settings.cfg")
#     print("Parsed Config:")
#     for section, entries in config.items():
#         print(f"[{section}]")
#         for k, v in entries.items():
#             print(f"{k} = {v}")
#         print()
#
# if __name__ == "__main__":
#     main()
# ```
#
# ### Key Changes:
# - **Warning for Keys Before Sections**: Added a print statement to warn when key-value pairs are found before any section.
# - **Split on First `=`**: Changed `line.split('=')` to `line.split('=', 1)` to ensure that only the first `=` is used for splitting, allowing for values that contain `=` signs.
# - **Warning for Malformed Lines**: Added a warning for lines that do not contain an `=` sign.
#
# These changes should make your config parser more robust and user-friendly.
# Assistant: Certainly! Unit tests are an essential part of ensuring that your code behaves as expected. Below are some suggested unit tests for your `parse_config` function. These tests will cover various scenarios, including valid configurations, edge cases, and error handling.
#
# You can use the `unittest` framework in Python to implement these tests. Here's how you can structure your tests:
#
# ```python
# import unittest
# import os
#
# def parse_config(filepath):
#     config = {}
#     current_section = None
#
#     with open(filepath, 'r') as f:
#         for line in f:
#             line = line.strip()
#             if not line or line.startswith("#"):
#                 continue
#             if line.startswith("[") and line.endswith("]"):
#                 current_section = line[1:-1]
#                 config[current_section] = {}
#             else:
#                 if current_section is None:
#                     print(f"Warning: Found key-value pair before any section: {line}")
#                     continue
#                 if '=' in line:
#                     key, value = line.split('=', 1)  # Split only on the first '='
#                     config[current_section][key.strip()] = value.strip()
#                 else:
#                     print(f"Warning: Malformed line (no '=' found): {line}")
#     return config
#
# class TestParseConfig(unittest.TestCase):
#
#     def setUp(self):
#         # Create a temporary config file for testing
#         self.test_file = 'test_config.cfg'
#
#     def tearDown(self):
#         # Remove the test file after tests
#         if os.path.exists(self.test_file):
#             os.remove(self.test_file)
#
#     def test_valid_config(self):
#         with open(self.test_file, 'w') as f:
#             f.write("[Section1]\n")
#             f.write("key1=value1\n")
#             f.write("key2=value2\n")
#             f.write("[Section2]\n")
#             f.write("keyA=valueA\n")
#
#         expected = {
#             "Section1": {"key1": "value1", "key2": "value2"},
#             "Section2": {"keyA": "valueA"}
#         }
#         result = parse_config(self.test_file)
#         self.assertEqual(result, expected)
#
#     def test_empty_file(self):
#         with open(self.test_file, 'w') as f:
#             f.write("")
#
#         expected = {}
#         result = parse_config(self.test_file)
#         self.assertEqual(result, expected)
#
#     def test_ignore_comments(self):
#         with open(self.test_file, 'w') as f:
#             f.write("# This is a comment\n")
#             f.write("[Section]\n")
#             f.write("key=value\n")
#
#         expected = {
#             "Section": {"key": "value"}
#         }
#         result = parse_config(self.test_file)
#         self.assertEqual(result, expected)
#
#     def test_keys_before_section(self):
#         with open(self.test_file, 'w') as f:
#             f.write("key=value\n")
#             f.write("[Section]\n")
#             f.write("key2=value2\n")
#
#         expected = {
#             "Section": {"key2": "value2"}
#         }
#         result = parse_config(self.test_file)
#         self.assertEqual(result, expected)
#         # Check for warning message (you may want to capture stdout)
#
#     def test_malformed_line(self):
#         with open(self.test_file, 'w') as f:
#             f.write("[Section]\n")
#             f.write("key_without_value\n")
#
#         expected = {
#             "Section": {}
#         }
#         result = parse_config(self.test_file)
#         self.assertEqual(result, expected)
#         # Check for warning message (you may want to capture stdout)
#
#     def test_multiple_equals_in_value(self):
#         with open(self.test_file, 'w') as f:
#             f.write("[Section]\n")
#             f.write("key=val1=val2\n")
#
#         expected = {
#             "Section": {"key": "val1=val2"}
#         }
#         result = parse_config(self.test_file)
#         self.assertEqual(result, expected)
#
# if __name__ == "__main__":
#     unittest.main()
# ```
#
# ### Explanation of the Tests:
# 1. **`test_valid_config`**: Tests parsing a valid config file with multiple sections and key-value pairs.
# 2. **`test_empty_file`**: Tests the behavior when the config file is empty. It should return an empty dictionary.
# 3. **`test_ignore_comments`**: Tests that comments are ignored correctly.
# 4. **`test_keys_before_section`**: Tests that key-value pairs before any section are ignored but do not raise an error.
# 5. **`test_malformed_line`**: Tests how the parser handles a line that does not have an `=` sign.
# 6. **`test_multiple_equals_in_value`**: Tests that values can contain `=` signs, ensuring only the first `=` is used for splitting.
#
# ### Note:
# - The tests create and remove a temporary config file for each test case using
